# %% [markdown]
# <a href="https://colab.research.google.com/github/afshanathani24-ux/afsha_nathani/blob/main/Loan_Interest_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input your numbers
Loan_amount = 20000
interest_rate = 0.10 # 10% interest
years = 2
# The formula (Interest = Principal* Rate * Time)
total_interest = Loan_amount * interest_rate * years
# print (f" for a $ {loan_amount} loan ...)"
print(f"The total interest over {years} years is: ${total_interest}")
# Out:
# The total interest over 2 years is: $4000.0
